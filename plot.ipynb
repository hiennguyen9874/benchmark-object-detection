# %%
import matplotlib.pyplot as plt

# %%
data = [
    ("YOLOv8", "YOLOv8-n", 572.67, 2.00586, 647.276, 0.373, 0.526, "r"),
    ("YOLOv8", "YOLOv8-s", 318.91, 3.54181, 343.913, 0.448, 0.617, "r"),
    ("YOLOv8", "YOLOv8-m", 154.71, 7.20209, 161.416, 0.501, 0.671, "r"),
    ("YOLOv8", "YOLOv8-l", 101.09, 10.617, 104.364, 0.527, 0.697, "r"),
    ("YOLOv8", "YOLOv8-x", 67.22, 16.6089, 68.6962, 0.537, 0.707, "r"),
    ("YOLOv9", "YOLOv9-t", 369.57, 3.10204, 400.717, 0.383, 0.531, "g"),
    ("YOLOv9", "YOLOv9-s", 245.04, 4.41357, 259.683, 0.467, 0.631, "g"),
    ("YOLOv9", "YOLOv9-m", 140.00, 7.8609, 145.698, 0.511, 0.678, "g"),
    ("YOLOv9", "YOLOv9-c", 126.93, 8.49884, 132.231, 0.529, 0.701, "g"),
    ("YOLOv9", "YOLOv9-e", 55.35, 20.5296, 56.3059, 0.555, 0.727, "g"),
    ("YOLO11", "YOLO11-n", 539.31, 2.15894, 606.265, 0.392, 0.551, "b"),
    ("YOLO11", "YOLO11-s", 313.79, 3.49353, 338.597, 0.465, 0.635, "b"),
    ("YOLO11", "YOLO11-m", 168.75, 6.55048, 177.052, 0.513, 0.682, "b"),
    ("YOLO11", "YOLO11-l", 130.65, 8.25171, 135.618, 0.531, 0.699, "b"),
    ("YOLO11", "YOLO11-x", 73.69, 14.0748, 74.572, 0.544, 0.714, "b"),
]

data_line = (
    ("YOLOv8-n", "YOLOv8-s", "r", "solid"),
    ("YOLOv8-s", "YOLOv8-m", "r", "solid"),
    ("YOLOv8-m", "YOLOv8-l", "r", "solid"),
    ("YOLOv8-l", "YOLOv8-x", "r", "solid"),
    
    ("YOLOv9-t", "YOLOv9-s", "g", "dotted"),
    ("YOLOv9-s", "YOLOv9-m", "g", "dotted"),
    ("YOLOv9-m", "YOLOv9-c", "g", "dotted"),
    ("YOLOv9-c", "YOLOv9-e", "g", "dotted"),
    
    ("YOLO11-n", "YOLO11-s", "b", "dashed"),
    ("YOLO11-s", "YOLO11-m", "b", "dashed"),
    ("YOLO11-m", "YOLO11-l", "b", "dashed"),
    ("YOLO11-l", "YOLO11-x", "b", "dashed"),
)

# %%
group_data = {x[1]: x for x in data}

# %%
plt.rcParams["figure.figsize"] = (7, 8)

import itertools

marker = itertools.cycle(
    [
        ".",
        ",",
        "o",
        "v",
        "^",
        "<",
        ">",
        "1",
        "2",
        "3",
        "4",
        "s",
        "p",
        "*",
        "h",
        "H",
        "+",
        "x",
        "D",
        "d",
        "|",
        "_",
    ]
)

for group_name, model_name, fps, latency, throughput, map, map05, color in data:
    plt.scatter(fps, map, label=model_name, color=color, marker=next(marker))

for from_name, to_name, color, linestyle in data_line:
    plt.plot(
        (group_data[from_name][2], group_data[to_name][2]),
        (group_data[from_name][5], group_data[to_name][5]),
        color=color,
        linestyle=linestyle,
    )

plt.legend()
plt.xlabel("Deepstream FPS")
plt.ylabel("mAP 0.5:0.95")
plt.gca().invert_xaxis()
plt.show()

# %%
plt.rcParams["figure.figsize"] = (7, 8)

import itertools

marker = itertools.cycle(
    [
        ".",
        ",",
        "o",
        "v",
        "^",
        "<",
        ">",
        "1",
        "2",
        "3",
        "4",
        "s",
        "p",
        "*",
        "h",
        "H",
        "+",
        "x",
        "D",
        "d",
        "|",
        "_",
    ]
)

for group_name, model_name, fps, latency, throughput, map, map05, color in data:
    plt.scatter(latency, map, label=model_name, color=color, marker=next(marker))

for from_name, to_name, color, linestyle in data_line:
    plt.plot(
        (group_data[from_name][3], group_data[to_name][3]),
        (group_data[from_name][5], group_data[to_name][5]),
        color=color,
        linestyle=linestyle,
    )

plt.legend()
plt.xlabel("Latency")
plt.ylabel("mAP 0.5:0.95")
# plt.gca().invert_xaxis()
plt.show()

# %%
plt.rcParams["figure.figsize"] = (7, 8)

import itertools

marker = itertools.cycle(
    [
        ".",
        ",",
        "o",
        "v",
        "^",
        "<",
        ">",
        "1",
        "2",
        "3",
        "4",
        "s",
        "p",
        "*",
        "h",
        "H",
        "+",
        "x",
        "D",
        "d",
        "|",
        "_",
    ]
)

for group_name, model_name, fps, latency, throughput, map, map05, color in data:
    plt.scatter(throughput, map, label=model_name, color=color, marker=next(marker))

for from_name, to_name, color, linestyle in data_line:
    plt.plot(
        (group_data[from_name][4], group_data[to_name][4]),
        (group_data[from_name][5], group_data[to_name][5]),
        color=color,
        linestyle=linestyle,
    )

plt.legend()
plt.xlabel("Throughput")
plt.ylabel("mAP 0.5:0.95")
plt.gca().invert_xaxis()
plt.show()
